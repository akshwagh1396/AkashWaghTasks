# %%
'''

1. Why are functions advantageous to have in your programs?

-> Function reduces repeatative line of code. Code size will reduce and code will become easy to read. At one we will create code can use multiple times





2. When does the code in a function run: when it's specified or when it's called?

-> code in a function runs, when it's called





3. What statement creates a function?

-> def





4. What is the difference between a function and a function call?
->Function is set of lines of code to perform particular task
& function call is calling that fuction to perform particular task in actual








5. How many global scopes are there in a Python program? How many local scopes?
-> In python mainly there is only 1 global scope per program & 1 local scope per function








6. What happens to variables in a local scope when the function call returns?
->
The variables in a local only exists while the function is being executed.
as soon as the execution of the function terminates or returns, the local variables are destroyed







7. What is the concept of a return value? Is it possible to have a return value in an expression?

->Return value means function giving/returning some value to caller of funtion
after its execution. Function can return 3+5, return 1 or return another function or can any value 







8. If a function does not have a return statement, what is the return value of a call to that function?

->It will be 'None'







9. How do you make a function variable refer to the global variable?
-> We will use global keyword before variable i.e. will define variable with global keyword
for eg:
   global a
   a=10





10. What is the data type of None? 
-> NoneType








11. What does the sentence import areallyourpetsnamederic do?

->It will find and load (import), areallyourpetsnamederic module in our current program so we can able to accces its defined methods if any







12. If you had a bacon() feature in a spam module, what would you call it after importing spam?
-> 

   import spam     #After importing spam, we will call its method
  
   spam.bacon() 






13. What can you do to save a programme from crashing if it encounters an error?

-> We will do error handling in program so if any error occured in program then it will get handled, 
we will get error description and gracefully exit the process that caused an error







14. What is the purpose of the try clause? What is the purpose of the except clause?

-> Try and clause block used for error handling purpose
   To handle error gracefully in progtram we can write our main code in try block.
   If there is no error than try block will execute succesfully, if got error in prceding try block than code inside execpt block will run
  





'''
