# %%
'''


1. What exactly is []?

-> Empty list


2. In a list of values stored in a variable called spam, how would you assign the value 'hello' as the third value? (Assume [2, 4, 6, 8, 10] are in spam.)
Let's pretend the spam includes the list ['a', 'b', 'c', 'd'] for the next three queries.

->spam[2]='hello'






3. What is the value of spam[int(int('3' * 2) / 11)]?

->'d'







4. What is the value of spam[-1]?

->'d'






5. What is the value of spam[:2]?

->['a', 'b']









Let's pretend bacon has the list [3.14, 'cat,' 11, 'cat,' True] for the next three questions.
6. What is the value of bacon.index('cat')?

-> 1











7. How does bacon.append(99) change the look of the list value in bacon?

->bacon.append(99) will insert 99 at last in list so we will get [3.14, 'cat', 11, 'cat', True, 99]








8. How does bacon.remove('cat') change the look of the list in bacon?

->After removing cat will get, [3.14, 11, 'cat', True, 99]






9. What are the list concatenation and list replication operators?

-> 
Using '+' oprator we can do list concatination, for e.g.
 L1=[1,2]
L2=[5,6]
L3=L1+L2
So we get [1, 2, 5, 6] in L3


Using '*' oprator we can replicatate list by given no. of times
L4=[1,2]
L5=3*L4
So we get [1, 2, 1, 2, 1, 2] in L5








10. What is difference between the list methods append() and insert()?

-> append will put/add given object inside list at end of list, takes only 1 arument (obj)
and insert will put/add  object at spefied index / location, takes 2 argument (index value ,obj)






11. What are the two methods for removing items from a list?
->
	pop and remove






12. Describe how list values and string values are identical.

-> List and string similar in some aspect, both are sequence and collection of values
We can accesas values in string and list. We can do slicing is string and list






13. What's the difference between tuples and lists?

->
List is collection that ordered and can be changeable, can be create using []
Tuples is collection that ordered and  not changeable, can be create using ()




14. How do you type a tuple value that only contains the integer 42?
-> You can do like below give comma  after 42 so it will converted into tuple
Tuple_a=(42,)










15. How do you get a list value's tuple form? How do you get a tuple value's list form?

->
For e.g.  below are random list and tuple

list1=[0,-1,-5]
tuple1=(1,2,3)

So to get a list value's tuple form=> tuple(list1)
& to get a tuple value's list form=> list(tuple1) 








16. Variables that "contain" list values are not necessarily lists themselves. Instead, what do they contain?

-> They contained references to list values.








17. How do you distinguish between copy.copy() and copy.deepcopy()?

-> copy.copy() is used for shallow copy, this function does not copy of original elements instead it is just storing refrence original elements 
 if we modify that object than original object also get modify or vice versa 
   
copy.deepcopy() is used for deep copy, this function copies original element  in new object so if modify element in copied object
 does not affect original element






'''
