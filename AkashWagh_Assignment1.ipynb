# %%
'''



1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.

*       ->Expression 
'hello' ->Value 
-87.8   ->Value  
-       ->Expression
/       ->Expression
6       ->Value 






2. What is the difference between string and variable?

-> We can store string in variable but vice versa not possible also within single qutoes string value can be anything 
but for variable its name should be as per defined rule
as String is nothing but value/data type/no of character(s)
variable is simpy just name of memory location/ref to memory location





3. Describe three different data types.

int   -> It is used for all integer values eg. ...-1, 0, 1...
str   -> It is for string values/no of characters.  
float -> Used for decimal values





4. What is an expression made up of? What do all expressions do?

-> Expression is made up of some no of values and operators. After evaluating expressions will give particular value






5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?

->
-Statements is nothing but we are giving some instruction/command to get some work done, 
for example print statement prints expected results / spam = 10...10 will assign to variable 'spam'.
-Expression is made up of some no of values and operators. After evaluating expressions will give particular value
-difference statement does not returing any value but expressions will give particular value after evaluation






6. After running the following code, what does the variable bacon contain?
bacon = 22
bacon + 1

-> 22 (because after adding 1 we are not storing value in bacon variable so it will show existing value) 



7. What should the values of the following two terms be?

'spam' + 'spamspam'   ->spamspamspam
'spam' * 3            ->spamspamspam





8. Why is eggs a valid variable name while 100 is invalid?

-> As per python standard variable rules of variable naming, egg is valid, 100 is not valid. Variable name should not start with number
 & 100 is complete integer should not be variable






9. What three functions can be used to get the integer, floating-point number, or string version of a value?

-> int(), float(), str()






10. Why does this expression cause an error? How can you fix it?
'I have eaten ' + 99 + ' burritos.'

-> We can't add string + integer
If we want to add than that integer 1st need to be conver into string, than it will work

for example to fix above-
print ('I have eaten ' + str(99) + ' burritos.')
output- I have eaten 99 burritos.


'''
